# %% [markdown]
# <a href="https://colab.research.google.com/github/sarakamdod10/Python-data-analysis-projects/blob/main/XKCD_COMICS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/Xkcd"

# %%
res = requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %%
data = res.text

# %%
data
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>xkcd - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"4eaa277c-e6a7-45ec-81af-1b30f1d6aabf","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Xkcd","wgTitle":"Xkcd","wgCurRevisionId":983665507,"wgRevisionId":983665507,"wgArticleId":10825442,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short description is different from Wikidata","Use mdy dates from April 2018","Use American English from December 2012","All Wikipedia articles written i
# ...

# %%
type(data)
# Out:
# str

# %%
soup = BeautifulSoup(res.text, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>xkcd - Wikipedia</title>
# ...

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
d = soup.select('a')

# %%
d
# Out:
# [<a id="top"></a>,
#  <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>,
#  <a class="mw-jump-link" href="#searchInput">Jump to search</a>,
#  <a class="image" href="/wiki/File:Xkcd_philosophy.png"><img alt="Xkcd philosophy.png" data-file-height="224" data-file-width="164" decoding="async" height="224" src="//upload.wikimedia.org/wikipedia/commons/b/b5/Xkcd_philosophy.png" width="164"/></a>,
#  <a href="#cite_note-comic220-1">[‡ 1]</a>,
#  <a href="/wiki/Author" title="Author">Author(s)</a>,
#  <a href="/wiki/Randall_Munroe" title="Randall Munroe">Randall Munroe</a>,
#  <a class="external text" href="https://xkcd.com/" rel="nofollow">xkcd.com</a>,
#  <a href="#cite_note-telegraph1-2">[1]</a>,
#  <a href="/wiki/Geek" title="Geek">Geek</a>,
#  <a href="#cite_note-aboutxkcd-3">[‡ 2]</a>,
#  <a href="/wiki/Webcomic" title="Webcomic">webcomic</a>,
#  <a href="/wiki/Randall_Munroe" title="Randall Munroe">Randall Munroe</a>,
#  <a href="#cite_note-telegraph1-2">[1]</a>,
# ...

# %%
soup.select('tr')
# Out:
# [<tr><th class="summary" colspan="2" style="text-align:center;font-size:125%;font-weight:bold;font-style: italic; background-color: ; color:">xkcd</th></tr>,
#  <tr><td colspan="2" style="text-align:center"><a class="image" href="/wiki/File:Xkcd_philosophy.png"><img alt="Xkcd philosophy.png" data-file-height="224" data-file-width="164" decoding="async" height="224" src="//upload.wikimedia.org/wikipedia/commons/b/b5/Xkcd_philosophy.png" width="164"/></a><div>Panel from "Philosophy"<sup class="reference" id="cite_ref-comic220_1-0"><a href="#cite_note-comic220-1">[‡ 1]</a></sup></div></td></tr>,
#  <tr><th scope="row"><a href="/wiki/Author" title="Author">Author(s)</a></th><td><a href="/wiki/Randall_Munroe" title="Randall Munroe">Randall Munroe</a></td></tr>,
#  <tr><th scope="row">Website</th><td><a class="external text" href="https://xkcd.com/" rel="nofollow">xkcd.com</a></td></tr>,
#  <tr><th scope="row">Current status/schedule</th><td>Mondays, Wednesdays, and Fridays</td></tr>,
# ...

# %%
for i in d:
  print(i.text)
# Out:
# Jump to navigation
# Jump to search
#
# [‡ 1]
# Author(s)
# Randall Munroe
# xkcd.com
# [1]
# Geek
# [‡ 2]
# webcomic
# Randall Munroe
# [1]
# tagline
# [‡ 3]
# [2]
# initialism
# mathematical
# programming
# scientific
# in-jokes
# pop-culture
# stick figures
# [3]
# [4]
# charts
# fractals
# [5]
# [‡ 2]
# [6]
# spinoff
# What If?
# [‡ 4]
# [‡ 5]
# [7]
# Thing Explainer
# most commonly used words in English
# [‡ 6]
# [8]
# How To
# [‡ 7]
# 1 History
# 2 Influences
# 3 Recurring themes
# 4 Inspired activities
# 5 Awards and recognition
# 6 Books
# 7 See also
# 8 References
# 8.1 Primary sources
# 9 Further reading
# 10 External links
# edit
#
#
# Randall Munroe
# margins
# scanning
# [9]
# doodles
# website
# strings
# [10]
# [‡ 8]
# [11]
# Syracuse
# Post-Standard
# [12]
# [10]
# [‡ 9]
# [13]
# [14]
# [9]
# Time
# EDT
# time lapse
# frames
# tooltip
# sandcastle
# The A.V. Club
# [15]
# Cory Doctorow
# Boing Boing
# [‡ 10]
# [16]
# Hugo Award for Best Graphic Story
# ...

# %%
df = pd.read_html(i)

# %%
df
# Out:
# [                           xkcd                            xkcd.1
#  0  Panel from "Philosophy"[‡ 1]      Panel from "Philosophy"[‡ 1]
#  1                     Author(s)                    Randall Munroe
#  2                       Website                          xkcd.com
#  3       Current status/schedule  Mondays, Wednesdays, and Fridays
#  4                   Launch date   September 2005; 15 years ago[1]
#  5                      Genre(s)                Comedy, Geek humor,
#      0                                             1
#  0 NaN  Wikimedia Commons has media related to xkcd.,
#      0                                          1
#  0 NaN  Wikiquote has quotations related to: xkcd,
#    vteRandall Munroe                          vteRandall Munroe.1
#  0        Solo works  xkcd "Time" What if? Thing Explainer How To
#  1           Related                 Machine of Death 4942 Munroe]

# %%
len(df)
# Out:
# 4

# %%
df[0]
# Out:
#                            xkcd                            xkcd.1
# 0  Panel from "Philosophy"[‡ 1]      Panel from "Philosophy"[‡ 1]
# 1                     Author(s)                    Randall Munroe
# 2                       Website                          xkcd.com
# 3       Current status/schedule  Mondays, Wednesdays, and Fridays
# 4                   Launch date   September 2005; 15 years ago[1]
# 5                      Genre(s)                Comedy, Geek humor

# %%
df[1]
# Out:
#     0                                             1
# 0 NaN  Wikimedia Commons has media related to xkcd.
